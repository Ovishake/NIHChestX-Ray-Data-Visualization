# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

train = pd.read_csv('/Users/ovishake/Downloads/train.csv')
# train = train.drop_duplicates(subset='Patient ID')
test = pd.read_csv('/Users/ovishake/Downloads/valid.csv')
# test = test.drop_duplicates(subset='Patient ID')
validation = pd.read_csv('/Users/ovishake/Downloads/test.csv')
# validation = validation.drop_duplicates(subset='Patient ID')

whole = train.append(test)
whole = whole.append(validation)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(whole['Finding Labels'])
x = le.transform(whole['Finding Labels'].values)
whole['IntEncode'] = x
whole['IntEncode']
# Out:
# 0       309
# 1       387
# 2       354
# 3       813
# 4       761
# 5       761
# 6       761
# 7       762
# 8       761
# 9       761
# 10      761
# 11      761
# 12      803
# 13      813
# 14      813
# 15      813
# 16      813
# 17      813
# 18      813
# 19      772
# 20      641
# 21      813
# 22      813
# 23      309
# 24      813
# 25      814
# 26      690
# 27      772
# 28      591
# 29      813
#        ...
# 4609    199
# 4610    414
# 4611    591
# 4612    414
# 4613    276
# 4614    772
# 4615    813
# 4616      0
# 4617     59
# 4618    414
# 4619     59
# 4620    414
# 4621    813
# 4622    813
# 4623      0
# 4624    813
# 4625    179
# 4626    813
# 4627     33
# 4628    354
# 4629    354
# 4630    813
# 4631    814
# 4632    813
# 4633    813
# 4634    514
# 4635    813
# 4636    813
# 4637    813
# 4638    354
# Name: IntEncode, Length: 111987, dtype: int64

# %%
whole.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111987 entries, 0 to 4638
# Data columns (total 11 columns):
# Image Index                    111987 non-null object
# Finding Labels                 111987 non-null object
# Follow-up #                    111987 non-null int64
# Patient ID                     111987 non-null int64
# Patient Age                    111987 non-null int64
# Patient Gender                 111987 non-null object
# View Position                  111987 non-null object
# OriginalImage[Width            111987 non-null int64
# Height]                        111987 non-null int64
# OriginalImagePixelSpacing[x    111987 non-null float64
# y]                             111987 non-null float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 10.3+ MB

# %%
print('train')
print(len(train.index))
print(whole['OriginalImagePixelSpacing[x'].describe())
sns.distplot(whole['OriginalImagePixelSpacing[x'])

# sns.distplot(whole['y]'])
# Out:
# train
# 106567
# count    111987.000000
# mean          0.155643
# std           0.016155
# min           0.115000
# 25%           0.143000
# 50%           0.143000
# 75%           0.168000
# max           0.198800
# Name: OriginalImagePixelSpacing[x, dtype: float64

# %%
sns.distplot(whole['y]'], color='green')

# %%
plt.figure(figsize=(8,8))
sns.heatmap(whole.corr(),
            vmin=-1,
            cmap='coolwarm',
            annot=True);

# %%
train = pd.read_csv('/Users/ovishake/Downloads/train.csv')
test = pd.read_csv('/Users/ovishake/Downloads/valid.csv')
validation = pd.read_csv('/Users/ovishake/Downloads/test.csv')

# %%
train.loc[['Patient Age','Finding Labels','Follow-up #']].sort_values('Follow-up #',ascending=True)
# Out:
#        Patient Age               Finding Labels  Follow-up #
# 36662           42                   No Finding            0
# 36663           35              Effusion|Nodule            1
# 36664           35  Atelectasis|Effusion|Nodule            2
# 36665           35                         Mass            3
# 36666           35                   No Finding            4
# 36667           35                   No Finding            5

# %%
whole = train.append(test)
whole = whole.append(validation)
# whole = whole.drop_duplicates(subset='Patient ID')

# %%
print(len(whole.index))
# Out:
# 111987

# %%
f, axarr = plt.subplots(7, 2, sharex=True,figsize=(35, 40))
pathology_list = ['Atelectasis', 'Consolidation', 'Infiltration', 'Pneumothorax', 'Edema', 'Emphysema', 'Fibrosis', 'Effusion', 'Pneumonia', 'Pleural_Thickening', 
'Cardiomegaly', 'Nodule', 'Mass', 'Hernia']
i=0
j=0
x=np.arange(0,100,10)
for pathology in pathology_list :
    g=sns.countplot(x='Patient Age', hue="Patient Gender",data=whole[whole['Finding Labels']==pathology], ax=axarr[i, j])
    axarr[i, j].set_title(pathology)   
    g.set_xlim(0,90)
    g.set_xticks(x)
    g.set_xticklabels(x)
    j=(j+1)%2
    if j==0:
        i=(i+1)%7
f.subplots_adjust(hspace=0.3)

# %%
import numpy as np
lab = whole['Finding Labels'].values
lab = np.array_repr(lab)

# %%
print(lab)
# Out:
# array(['Cardiomegaly', 'No Finding', 'Hernia', ..., 'No Finding',
#        'No Finding', 'No Finding'], dtype=object)

# %%
print(type(lab))
# Out:
# <type 'str'>

# %%
lab = lab.decode('utf-8').split('|')

# %%
print(lab)
# Out:
# [u"array(['Cardiomegaly', 'No Finding', 'Hernia', ..., 'No Finding',\n       'No Finding', 'No Finding'], dtype=object)"]

# %%
lab1 = lab[5:]

# %%
lab1
# Out:
# u"['Cardiomegaly', 'No Finding', 'Hernia', ..., 'No Finding',\n       'No Finding', 'No Finding'], dtype=object)"

# %%
print(type(lab1))
# Out:
# <type 'unicode'>

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

train = pd.read_csv('/Users/ovishake/Downloads/train.csv')
# train = train.drop_duplicates(subset='Patient ID')
test = pd.read_csv('/Users/ovishake/Downloads/valid.csv')
# test = test.drop_duplicates(subset='Patient ID')
validation = pd.read_csv('/Users/ovishake/Downloads/test.csv')
# validation = validation.drop_duplicates(subset='Patient ID')

# %%
whole = train.append(test)
whole = whole.append(validation)
# whole = whole.drop_duplicates(subset='Patient ID')

# %%
whole['Follow-up #'].groupby(whole['Finding Labels']).describe()
# Out:
#                                                       count       mean  \
# Finding Labels
# Atelectasis                                          4215.0   7.296085
# Atelectasis|Cardiomegaly                               88.0   6.500000
# Atelectasis|Cardiomegaly|Consolidation                 10.0   4.700000
# Atelectasis|Cardiomegaly|Consolidation|Edema            1.0   6.000000
# Atelectasis|Cardiomegaly|Consolidation|Edema|Ef...      2.0   6.000000
# Atelectasis|Cardiomegaly|Consolidation|Edema|Ef...      1.0  36.000000
# Atelectasis|Cardiomegaly|Consolidation|Edema|Ef...      1.0  31.000000
# Atelectasis|Cardiomegaly|Consolidation|Edema|Ef...      1.0  13.000000
# Atelectasis|Cardiomegaly|Consolidation|Edema|Ef...      2.0  21.500000
# Atelectasis|Cardiomegaly|Consolidation|Effusion         9.0  22.222222
# Atelectasis|Cardiomegaly|Consolidation|Effusion...     12.0  22.083333
# Atelectasis|Cardiomegaly|Consolidation|Effusion...      1.0   4.000000
# ...

# %%
print(grp)

# %%
sns.distplot(whole['OriginalImage[Width'], kde=True)

# %%
sns.distplot(whole['P'], kde=True)

# %%
ax = sns.scatterplot(x="OriginalImage[Width", y="Height]", size='Patient Age', hue='Patient Gender', data=whole)

# %%
sns.jointplot(x="OriginalImage[Width", y="Height]", data=whole, kind="kde")

# %%
df = pd.read_csv('/Users/ovishake/Downloads/BBox_List_2017.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 9 columns):
# Image Index      984 non-null object
# Finding Label    984 non-null object
# Bbox [x          984 non-null float64
# y                984 non-null float64
# w                984 non-null float64
# h]               984 non-null float64
# Unnamed: 6       0 non-null float64
# Unnamed: 7       0 non-null float64
# Unnamed: 8       0 non-null float64
# dtypes: float64(7), object(2)
# memory usage: 69.3+ KB

# %%
f, ax = plt.subplots(figsize=(9, 9))
sns.heatmap(df.corr(),
            vmin=-1,
            cmap='YlGnBu',
            annot=True);

# %%
sns.jointplot(x="w", y="h]", data=df, kind="kde")

# %%
dt = whole[whole['Follow-up #']==1]

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 11 columns):
# Image Index                    0 non-null object
# Finding Labels                 0 non-null object
# Follow-up #                    0 non-null int64
# Patient ID                     0 non-null int64
# Patient Age                    0 non-null int64
# Patient Gender                 0 non-null object
# View Position                  0 non-null object
# OriginalImage[Width            0 non-null int64
# Height]                        0 non-null int64
# OriginalImagePixelSpacing[x    0 non-null float64
# y]                             0 non-null float64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 0.0+ bytes

# %%
whole['dist'] = 1
g = whole.groupby('Follow-up #').count()
g.info()
g.head()
g.reset_index(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 0 to 183
# Data columns (total 11 columns):
# Image Index                    184 non-null int64
# Finding Labels                 184 non-null int64
# Patient ID                     184 non-null int64
# Patient Age                    184 non-null int64
# Patient Gender                 184 non-null int64
# View Position                  184 non-null int64
# OriginalImage[Width            184 non-null int64
# Height]                        184 non-null int64
# OriginalImagePixelSpacing[x    184 non-null int64
# y]                             184 non-null int64
# dist                           184 non-null int64
# dtypes: int64(11)
# memory usage: 17.2 KB

# %%
# g['dist'] = g['dist'] - g['dist'].mean()
g.head()
# Out:
#    Follow-up #  Image Index  Finding Labels  Patient ID  Patient Age  \
# 0            0        30775           30775       30775        30775
# 1            1        13291           13291       13291        13291
# 2            2         9182            9182        9182         9182
# 3            3         7084            7084        7084         7084
# 4            4         5755            5755        5755         5755
#
#    Patient Gender  View Position  OriginalImage[Width  Height]  \
# 0           30775          30775                30775    30775
# 1           13291          13291                13291    13291
# 2            9182           9182                 9182     9182
# 3            7084           7084                 7084     7084
# 4            5755           5755                 5755     5755
#
#    OriginalImagePixelSpacing[x     y]   dist
# 0                        30775  30775  30775
# 1                        13291  13291  13291
# ...

# %%
g['dist'].head()
# Out:
# 0    30775
# 1    13291
# 2     9182
# 3     7084
# 4     5755
# Name: dist, dtype: int64

# %%
# Out:
#        Image Index  Finding Labels   Patient ID  Patient Age  Patient Gender  \
# count    184.00000       184.00000    184.00000    184.00000       184.00000
# mean     608.62500       608.62500    608.62500    608.62500       608.62500
# std     2681.66562      2681.66562   2681.66562   2681.66562      2681.66562
# min        1.00000         1.00000      1.00000      1.00000         1.00000
# 25%        5.00000         5.00000      5.00000      5.00000         5.00000
# 50%       19.00000        19.00000     19.00000     19.00000        19.00000
# 75%      179.50000       179.50000    179.50000    179.50000       179.50000
# max    30775.00000     30775.00000  30775.00000  30775.00000     30775.00000
#
#        View Position  OriginalImage[Width      Height]  \
# count      184.00000            184.00000    184.00000
# mean       608.62500            608.62500    608.62500
# std       2681.66562           2681.66562   2681.66562
# ...

# %%
sns.distplot(g['dist'])

# %%
print('Starting bounding box of pathologies')

sns.scatterplot(x=df['Bbox [x'], y = df['y'])
sns.scatterplot(x=df['Bbox [x']+df['w'], y = df['y']+df['h]'], color='red')
# Out:
# Starting bounding box of pathologies

# %%
print('Ending point of pathologies')

sns.scatterplot(x=df['Bbox [x']+df['w'], y = df['y']+df['h]'])
# Out:
# Ending point of pathologies
